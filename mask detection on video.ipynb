# %% [markdown]
# # Face Mask  Detection using WebCam  and CNN_Model

# %% [markdown]
# ### Import Library

# %%
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

# %% [markdown]
# ### Load Model

# %%
# Accuracy=97.4 , validation Accuracy = 99.1 # very light model, size =5MB
model = load_model('model/cnn_model.h5') # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200

# %% [markdown]
# ### Load Cascade Classifier and detect Face

# %%
# Load the Cascade face Classifier

face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
#start  web cam
cap = cv2.VideoCapture(0) # for webcam

#cap = cv2.VideoCapture('videos/Mask - 34775.mp4') # for video

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    responce, color_img = cap.read()
    #color_img = cv2.imread('sandeep.jpg')
    
    #if respoce False the break the loop
    if responce == False:
        break    
    


    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) # 1.1, 3) for 1.mp4
    
    
    
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# user not wearing mask - prob =  0.52834827
# User with mask - predic =  0.56983227
# User with mask - predic =  0.5303265
# User with mask - predic =  0.50623965
# User with mask - predic =  0.5116512
# User with mask - predic =  0.5882378
# User with mask - predic =  0.5774613
# User with mask - predic =  0.66907114
# User with mask - predic =  0.6418932
# User with mask - predic =  0.7047284
# User with mask - predic =  0.6396163
# User with mask - predic =  0.6976035
# User with mask - predic =  0.69581246
# User with mask - predic =  0.5911359
# user not wearing mask - prob =  0.5155207
# User with mask - predic =  0.7327799
# User with mask - predic =  0.5899634
# User with mask - predic =  0.5135146
# User with mask - predic =  0.5331562
# user not wearing mask - prob =  0.6128425
# User with mask - predic =  0.7501644
# User with mask - predic =  0.7672882
# User with mask - predic =  0.73641473
# User with mask - predic =  0.72529626
# User with mask - predic =  0.7564767
# User with mask - predic =  0.6773925
# User with mask - predic =  0.73566943
# User with mask - predic =  0.7140324
# User with mask - predic =  0.6562065
# User with mask - predic =  0.6297086
# User with mask - predic =  0.6080599
# User with mask - predic =  0.6773726
# User with mask - predic =  0.67188156
# User with mask - predic =  0.70657957
# User with mask - predic =  0.6526787
# user not wearing mask - prob =  0.7955643
# user not wearing mask - prob =  0.78133976
# user not wearing mask - prob =  0.7861237
# user not wearing mask - prob =  0.7863837
# user not wearing mask - prob =  0.7802625
# user not wearing mask - prob =  0.7969983
# user not wearing mask - prob =  0.7909288
# user not wearing mask - prob =  0.79718846
# user not wearing mask - prob =  0.75759494
# user not wearing mask - prob =  0.7910054
# user not wearing mask - prob =  0.7910157
# user not wearing mask - prob =  0.8028821
# user not wearing mask - prob =  0.80159384
# user not wearing mask - prob =  0.7912224
# user not wearing mask - prob =  0.75488275
# user not wearing mask - prob =  0.78651476
# user not wearing mask - prob =  0.7767697
# user not wearing mask - prob =  0.76117927
# user not wearing mask - prob =  0.776464
# user not wearing mask - prob =  0.75660664
# user not wearing mask - prob =  0.80538005
# user not wearing mask - prob =  0.6642755
# user not wearing mask - prob =  0.76751494
# user not wearing mask - prob =  0.74845374
# user not wearing mask - prob =  0.74265873
# user not wearing mask - prob =  0.73862326
# user not wearing mask - prob =  0.71761215
# user not wearing mask - prob =  0.71846884
# user not wearing mask - prob =  0.7338967
# user not wearing mask - prob =  0.71925807
# user not wearing mask - prob =  0.72732913
# user not wearing mask - prob =  0.73912555
# user not wearing mask - prob =  0.7531791
# user not wearing mask - prob =  0.7437982
# user not wearing mask - prob =  0.74286234
# user not wearing mask - prob =  0.72971696
# user not wearing mask - prob =  0.7166469
# user not wearing mask - prob =  0.73434925
# user not wearing mask - prob =  0.73720783
